# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_table("./FreqValue/FreqValue20230427_6.txt", names=["signal1", "signal2", "num"], sep=" ")

# %%
dfsignal = df.signal1
a = dfsignal.mean()

# %%
mean_list = []
std_list = []
x = []
for i in range(1, 10):
    n_s = 200*(i-1)
    n_e = 200*i
    mean = dfsignal[n_s:n_e].mean()
    std = dfsignal[n_s:n_e].std()
    mean_list.append(mean)
    std_list.append(std)
    x.append(n_e)

plt.errorbar(x, mean_list, std_list, fmt=".")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# Out:
# signal1    7.269460e+06
# signal2    7.269460e+06
# num        1.000000e+00
# dtype: float64
# signal1    950.920651
# signal2    950.920651
# num          0.000000
# dtype: float64
