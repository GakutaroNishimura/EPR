# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./WaveData/scope_178.csv", names = ["time", "signal", "sync"], skiprows=2)
df = pd.read_csv("./WaveData/scope_196.csv", names = ["time", "signal", "sync", "sync2"], skiprows = 3)

# %%
plt.plot(df.time, df.signal)

plt.grid()
